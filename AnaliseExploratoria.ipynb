# %%
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_5c41e991519547ee999d0d6559668a5a = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='xK7kc79PKzR0S1vPTDbbagqVXBzLJjq4DizxHig0OYif',
    ibm_auth_endpoint="https://iam.cloud.ibm.com/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3-api.us-geo.objectstorage.service.networklayer.com')

body = client_5c41e991519547ee999d0d6559668a5a.get_object(Bucket='datachallenge-donotdelete-pr-pcheowyyfxb0xw',Key='Tabela3.xlsx')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

PMC = pd.read_excel(body)
PMC.head()
# Out:
#              Mês                                    Tipos de índice  \
# 0  dezembro 2019     Variação mês / mês anterior com ajuste sazonal
# 1            NaN                                                NaN
# 2            NaN  Variação mensal (base: igual mês do ano anterior)
# 3            NaN                                                NaN
# 4   janeiro 2020     Variação mês / mês anterior com ajuste sazonal
#
#                                             Variável  Unnamed: 3
# 0  Índice de volume de vendas no comércio varejis...        -0.4
# 1  Índice de receita nominal de vendas no comérci...         3.7
# 2  Índice de volume de vendas no comércio varejis...        -1.0
# 3  Índice de receita nominal de vendas no comérci...         3.9
# 4  Índice de volume de vendas no comércio varejis...         0.0

# %%
PMC.info
# Out:
# <bound method DataFrame.info of                Mês                                    Tipos de índice  \
# 0    dezembro 2019     Variação mês / mês anterior com ajuste sazonal
# 1              NaN                                                NaN
# 2              NaN  Variação mensal (base: igual mês do ano anterior)
# 3              NaN                                                NaN
# 4     janeiro 2020     Variação mês / mês anterior com ajuste sazonal
# 5              NaN                                                NaN
# 6              NaN  Variação mensal (base: igual mês do ano anterior)
# 7              NaN                                                NaN
# 8   fevereiro 2020     Variação mês / mês anterior com ajuste sazonal
# 9              NaN                                                NaN
# 10             NaN  Variação mensal (base: igual mês do ano anterior)
# 11             NaN                                                NaN
# ...

# %%
PMC.describe
# Out:
# <bound method NDFrame.describe of                Mês                                    Tipos de índice  \
# 0    dezembro 2019     Variação mês / mês anterior com ajuste sazonal
# 1              NaN                                                NaN
# 2              NaN  Variação mensal (base: igual mês do ano anterior)
# 3              NaN                                                NaN
# 4     janeiro 2020     Variação mês / mês anterior com ajuste sazonal
# 5              NaN                                                NaN
# 6              NaN  Variação mensal (base: igual mês do ano anterior)
# 7              NaN                                                NaN
# 8   fevereiro 2020     Variação mês / mês anterior com ajuste sazonal
# 9              NaN                                                NaN
# 10             NaN  Variação mensal (base: igual mês do ano anterior)
# 11             NaN                                                NaN
# ...

# %%
PMC.count
# Out:
# <bound method DataFrame.count of                Mês                                    Tipos de índice  \
# 0    dezembro 2019     Variação mês / mês anterior com ajuste sazonal
# 1              NaN                                                NaN
# 2              NaN  Variação mensal (base: igual mês do ano anterior)
# 3              NaN                                                NaN
# 4     janeiro 2020     Variação mês / mês anterior com ajuste sazonal
# 5              NaN                                                NaN
# 6              NaN  Variação mensal (base: igual mês do ano anterior)
# 7              NaN                                                NaN
# 8   fevereiro 2020     Variação mês / mês anterior com ajuste sazonal
# 9              NaN                                                NaN
# 10             NaN  Variação mensal (base: igual mês do ano anterior)
# 11             NaN                                                NaN
# ...

# %%
PMC.heatmap(PMC.corr(),annot-T)
